# %%
# 1

num = int(input('학생 번호: '))
# num

# (num-1) // 10
# 1~10 -> 0
# 11~20 -> 10
leader_num = ((num-1) // 10 * 10) +1

print(leader_num)
# Out:
# 21

# %%
# 2
try:
    num = int(input('숫자를 입력하세요'))

    if num % 2 == 0:
        print('짝수')
    else:
        print('홀수')
except ValueError as e:
    print('숫자만 입력하세요')
    # print(e)
# Out:
# 숫자만 입력하세요

# %%
# 3. 양수, 음수, 0 판별하기 (if~elif~else)

#정수를 입력받아 양수, 음수 또는 0을 출력하는 프로그램을 작성하시오.

num = int(input('숫자를 입력해주세요'))

if num > 0:
        print("양수")
elif num < 0:
        print("음수")
else: print(0)
# Out:
# 0

# %%
# 4. 20대 출입 가능 여부
# 두 사람의 나이를 입력받는다.
# 두 사람 모두 20대(20~29세)이면 출입 가능을 출력하고,
# 그 외에는 출입 불가를 출력하는 프로그램을 작성하시오.

num1 = int(input('첫 번째 나이를 입력해주세요'))
num2 = int(input('두 번째 나이를 입력해주세요'))

if (20 <= num1 <= 29) and (20 <= num2 <= 29):
    print('20대 입니다. 출입 가능') 
else: print('출입 불가!!!')
# Out:
# 20대 입니다. 출입 가능

# %%
# 5. 1~50 사이의 5의 배수 출력
# 1부터 50까지의 수 중 5의 배수만 출력하는 프로그램을 작성하시오.

# num = int(input('1~50사이의 숫자를 입력해주세요'))

# if num % 5 ==0:
#     print('5의 배수입니다.')
# else: print('5의 배수만 입력해주세요')
# Out:
# 5의 배수만 입력해주세요

# %%
num = range(1,51)

for nums in num:
    if nums % 5 ==0:
        print(nums)    


# for nums in range(1, 51):
#     if nums % 5 == 0:
#         print(nums)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
# 6. 1~10 사이 홀수의 합 구하기
# 1부터 10까지의 홀수의 합을 출력하는 프로그램을 작성하시오.

for nums in range(1,11):
    if nums % 2 == 1:
        print(nums)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i = 1
# 아래코드가 i(1~9)가 9번 반복
for i in range(1,10):
    for dan  in range(2,10):
        print(f'{dan} x {i} = {dan*i:>2}',end='|')
    print('',end='\n')
# Out:
# 2 x 1 =  2|3 x 1 =  3|4 x 1 =  4|5 x 1 =  5|6 x 1 =  6|7 x 1 =  7|8 x 1 =  8|9 x 1 =  9|
# 2 x 2 =  4|3 x 2 =  6|4 x 2 =  8|5 x 2 = 10|6 x 2 = 12|7 x 2 = 14|8 x 2 = 16|9 x 2 = 18|
# 2 x 3 =  6|3 x 3 =  9|4 x 3 = 12|5 x 3 = 15|6 x 3 = 18|7 x 3 = 21|8 x 3 = 24|9 x 3 = 27|
# 2 x 4 =  8|3 x 4 = 12|4 x 4 = 16|5 x 4 = 20|6 x 4 = 24|7 x 4 = 28|8 x 4 = 32|9 x 4 = 36|
# 2 x 5 = 10|3 x 5 = 15|4 x 5 = 20|5 x 5 = 25|6 x 5 = 30|7 x 5 = 35|8 x 5 = 40|9 x 5 = 45|
# 2 x 6 = 12|3 x 6 = 18|4 x 6 = 24|5 x 6 = 30|6 x 6 = 36|7 x 6 = 42|8 x 6 = 48|9 x 6 = 54|
# 2 x 7 = 14|3 x 7 = 21|4 x 7 = 28|5 x 7 = 35|6 x 7 = 42|7 x 7 = 49|8 x 7 = 56|9 x 7 = 63|
# 2 x 8 = 16|3 x 8 = 24|4 x 8 = 32|5 x 8 = 40|6 x 8 = 48|7 x 8 = 56|8 x 8 = 64|9 x 8 = 72|
# 2 x 9 = 18|3 x 9 = 27|4 x 9 = 36|5 x 9 = 45|6 x 9 = 54|7 x 9 = 63|8 x 9 = 72|9 x 9 = 81|
